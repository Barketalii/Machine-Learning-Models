# %% [markdown]
# <a href="https://colab.research.google.com/github/Barketalii/Machine-Learning-Models/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What is Supervised Learning?**
#
# Supervised Learning is a type of machine learning where we train a model using labeled data.
#
# Labeled data means each input (X) has a corresponding correct output (y).
#
# The model “learns” the relationship between inputs and outputs so it can predict outputs for new unseen inputs.
#
# 👉 Think of it like a teacher supervising a student:
#
# The teacher gives questions + correct answers.
#
# The student (model) learns the mapping.
#
# Later, when given only the question, the student predicts the

# %% [markdown]
# **Regression**
#
# Predicts a continuous value.
#
# Example: Predicting house price, temperature.
#
# Algorithms: Linear Regression, Ridge, Lasso, SVR.

# %% [markdown]
# import numpy and LinearRegression from sklearn.linear_model
# **numumPy** is a Python library for numerical computations.
# It provides arrays, matrices, and functions for efficient math operations.
# NumPy is faster and more memory-efficient than regular Python lists, which is why almost all ML workflows use it.
# **LinearRegression**
# It’s a machine learning model from Scikit-learn (sklearn).
# Linear regression is used for predicting a continuous target variable based on input features.
# Example: predicting house prices based on size, location, number of rooms.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
X=np.array([[1],[2],[3],[4],[5]])
y=np.array([[1],[4],[6],[8],[10]])

# %%
import seaborn as sns
sns.scatterplot(X)
# Out:
# <Axes: >

# %% [markdown]
# When we write LinearRegression(), we are creating an instance (object) of that class.
#
# model is the variable that holds this object.

# %%
model=LinearRegression()

# %% [markdown]
# **.fit**
# Training phase: the model learns patterns from X and y.
#
# Internally, it calculates weights, coefficients, or structures (depending on the algorithm).
#
# After .fit(), the model is ready to make predictions.

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
new_input=np.array([[6]])

# %%
pred_output=model.predict(new_input)

# %%
print(pred_output)
# Out:
# [[12.4]]
